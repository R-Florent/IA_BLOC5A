# %% [markdown]
# Consignes de travail
#
# Vous effectuerez les deux premiers tutoriels débutants de TensorFlow :
#
# https://www.tensorflow.org/tutorials/quickstart/beginner
#
# https://www.tensorflow.org/tutorials/keras/classification
#
# L'environnement doit être similaire à celui proposé par le guide de préparation de l'environnement. Il conviendra de créer un nouvel environnement virtuel pour éviter les conflits avec les bibliothèques des autres workshops. Une solution cloud telle qu'un environnement Google Colab est également envisageable

# %%
import tensorflow as tf
print("TensorFlow version: ", tf.__version__)
# Out:
# TensorFlow version:  2.20.0

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])

# %%
predictions = model(x_train[:1]).numpy()
predictions
# Out:
# array([[-0.7213657 ,  0.4312729 ,  0.63712376,  0.66791   ,  0.36490676,
#          0.4093606 ,  0.5136168 , -0.666457  , -0.2571874 , -0.08483645]],
#       dtype=float32)

# %%
tf.nn.softmax(predictions).numpy()
# Out:
# array([[0.03830642, 0.12129869, 0.14902394, 0.15368317, 0.1135099 ,
#         0.11866967, 0.13170965, 0.04046859, 0.06093427, 0.07239568]],
#       dtype=float32)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
loss_fn(y_train[:1], predictions).numpy()
# Out:
# np.float32(2.1314116)

# %%
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9142 - loss: 0.2952
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9575 - loss: 0.1435
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9666 - loss: 0.1079
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9729 - loss: 0.0876
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9759 - loss: 0.0760
